# %% [markdown]
# <a href="https://colab.research.google.com/github/michelle2526/dio--desafio-github-primeiro-rep-sitorio/blob/main/CURSO_BASICP_PTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PASSO A PASSO DE SOLUÇÃO E DESAFIO**

# %%
# logica de programação

# passo 0 - entender o dasafio que você quer resolver

# passo 1 - percorrer todos os arquivos da pasta base da dados (pasta vendas
import os
import pandas as pd


lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Básico de Python/Vendas")
display(lista_arquivo)
# Out:
# ['Vendas - Fortaleza.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - Salvador.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Devolucoes - São Paulo.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Curitiba.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Curitiba.csv']

# %%
tabela_total = pd.DataFrame()

# passo 2 - importar as bases de dados de vendas

for arquivo in lista_arquivo:
  # se tem "vendas" no nome do arquivo,então 

  if "Vendas" in arquivo:
    #importar o arquivo
   tabela = pd.read_csv(f"/content/drive/MyDrive/Curso Básico de Python/Vendas/{arquivo}")
  tabela_total = tabela_total.append(tabela)

# passo 3 - tratar /compilar as bases de dados
display(tabela_total)
# Out:
#      Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0             2  HL1148      Câmera                   2        Camila
# 1             3  HL1918      iPhone                   3         Clara
# 2             4  HL9962     Android                   4       Eduardo
# 3            11  HL1918      iPhone                   2        Rafael
# 4            15  HL2714      Tablet                   2          Caio
# ..          ...     ...         ...                 ...           ...
# 714        9859  HL2714      Tablet                   1         Júlio
# 715        9876  HL4379   Televisão                   5         Bruno
# 716        9918  HL1148      Câmera                   2         Lucas
# 717        9944  HL1918      iPhone                   5       Raphael
# 718        9998  HL7348  SmartWatch                   1      Vinícius
#
#     Sobrenome        Data       Loja  Preco Unitario  Unnamed: 8
# ...

# %%
# passo 4 - calcular o produto mais vendido (em quantidade)

tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida
# Produto
# iPhone                   16896
# Televisão                10761
# Android                   5951
# Notebook                  5899
# SmartWatch                5364
# Tablet                    5234
# Câmera                    5119

# %%
# passo 5 -calcular o produto qqque mais faturou ( em faturamento)
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']
tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         89548800
# Televisão      26902500
# Notebook       20646500
# Android        20233400
# Câmera         10749900
# Tablet          8374400
# SmartWatch      7509600
#             Faturamento
# Produto
# iPhone         89548800
# Televisão      26902500
# Notebook       20646500
# Android        20233400
# Câmera         10749900
# Tablet          8374400
# SmartWatch      7509600

# %%
# passo 6 -calcular a loja/cidade que mais vendeu ( em faturamento)- criar um grafico/dashboard
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte     32401500
# Curitiba           21181500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     59471200
# Salvador           13111300
# São Paulo          22098300

# %%
import plotly.express as px

grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
